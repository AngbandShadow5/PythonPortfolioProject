# %%
# U.S. Medical Insurance Costs

# %%
#Importing cabailites to read .csv files, plot data, and call functions from a separate Python file. 
import csv
import matplotlib.pyplot as plt
# %run MedicalInsuranceLibrary.ipynb

# %%
#Reading the file and saving the contents into a variable for
#easier manipulation.
insurance_csv_list = []
with open('insurance.csv', newline='') as insurance_csv_file:
    insurance_csv_dict = csv.DictReader(insurance_csv_file)
    for row in insurance_csv_dict:
        insurance_csv_list.append(row)

# %%
#Getting the average age of all the patients in the data set.
print("Average age in data set:", average_age(insurance_csv_list))
# Out:
# Average age in data set: 39.0

# %%
#Finding out where the majortity of the individuals are from.
individual_regions(insurance_csv_list)

# %%
#Finding costs between smokers and non-smokers.
non_smokers_vs_smokers(insurance_csv_list)

# %%
#Figure out what the average age is for someone who has at least one child in this dataset.
print("Average age of users who have at least 1 child:", average_age_one_child(insurance_csv_list))
# Out:
# Average age of users who have at least 1 child: 40.0

# %%
#Plotting BMI in relation to Costs. 
bmi_relation_to_cost(insurance_csv_list)

# %%
#Plotting Age in relation to Costs.
age_relation_to_cost(insurance_csv_list)

# %%
#Plotting Average Cost per Region.
average_cost_per_region(insurance_csv_list)
